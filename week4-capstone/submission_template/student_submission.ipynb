# %% [markdown]
# # Capstone Project: Online Orders Analysis

# %%
# Step 1: Load data
import pandas as pd
df = pd.read_csv('../data/online_orders.csv')

# %%
# Step 2: Clean (fill missing profit with median)
# YOUR CODE HERE

# %%
# Step 3: Answer Q1 - Region with highest sales
# YOUR CODE HERE

# %%
# Step 4: Export cleaned CSV for Tableau
df.to_csv('cleaned_orders.csv', index=False)

# %%
# Step 5: Add insights text cells
