# %% [markdown]
# # Exercise 1: Variables & Loops
#
# **Instructions:** Fill in the `# YOUR CODE HERE` sections.

# %% [markdown]
# ## Q1: Create a list of sales amounts
# sales = [100, 250, 75, 400, 120]
# # Loop through and print each amount doubled

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Q2: Count how many sales > 200

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Q3: (Challenge) Read sample_sales.csv and compute total revenue

# %%
# YOUR CODE HERE
